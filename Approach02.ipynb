# %% [markdown]
# ### Set up environment

# %%
# !pip install -r requirements.txt
# Out:
# Collecting nibabel==5.1.0 (from -r requirements.txt (line 1))
#   Downloading nibabel-5.1.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting matplotlib==3.5.1 (from -r requirements.txt (line 2))
#   Downloading matplotlib-3.5.1-cp310-cp310-win_amd64.whl.metadata (6.7 kB)
# Collecting scikit-image==0.20.0 (from -r requirements.txt (line 3))
#   Downloading scikit_image-0.20.0-cp310-cp310-win_amd64.whl.metadata (16 kB)
# Collecting scikit-learn==1.0.2 (from -r requirements.txt (line 4))
#   Downloading scikit_learn-1.0.2-cp310-cp310-win_amd64.whl.metadata (10 kB)
# Collecting opencv-python==4.7.0.68 (from -r requirements.txt (line 5))
#   Downloading opencv_python-4.7.0.68-cp37-abi3-win_amd64.whl.metadata (18 kB)
# Collecting tensorflow==2.8.4 (from -r requirements.txt (line 6))
#   Downloading tensorflow-2.8.4-cp310-cp310-win_amd64.whl.metadata (2.9 kB)
# Collecting keras==2.8.0 (from -r requirements.txt (line 7))
#   Downloading keras-2.8.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting kaggle==1.5.13 (from -r requirements.txt (line 8))
#   Downloading kaggle-1.5.13.tar.gz (63 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pandas==1.4.2 (from -r requirements.txt (line 9))
#   Downloading pandas-1.4.2-cp310-cp310-win_amd64.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.19 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from nibabel==5.1.0->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: packaging>=17 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from nibabel==5.1.0->-r requirements.txt (line 1)) (24.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib==3.5.1->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib==3.5.1->-r requirements.txt (line 2)) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib==3.5.1->-r requirements.txt (line 2)) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib==3.5.1->-r requirements.txt (line 2)) (10.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib==3.5.1->-r requirements.txt (line 2)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib==3.5.1->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.8 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from scikit-image==0.20.0->-r requirements.txt (line 3)) (1.14.0)
# Requirement already satisfied: networkx>=2.8 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from scikit-image==0.20.0->-r requirements.txt (line 3)) (3.3)
# Collecting imageio>=2.4.1 (from scikit-image==0.20.0->-r requirements.txt (line 3))
#   Downloading imageio-2.35.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting tifffile>=2019.7.26 (from scikit-image==0.20.0->-r requirements.txt (line 3))
#   Downloading tifffile-2024.9.20-py3-none-any.whl.metadata (32 kB)
# Collecting PyWavelets>=1.1.1 (from scikit-image==0.20.0->-r requirements.txt (line 3))
#   Downloading pywavelets-1.7.0-cp310-cp310-win_amd64.whl.metadata (9.0 kB)
# Collecting lazy_loader>=0.1 (from scikit-image==0.20.0->-r requirements.txt (line 3))
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: joblib>=0.11 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn==1.0.2->-r requirements.txt (line 4)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn==1.0.2->-r requirements.txt (line 4)) (3.5.0)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (24.3.25)
# Requirement already satisfied: gast>=0.2.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (3.11.0)
# Collecting keras-preprocessing>=1.1.1 (from tensorflow==2.8.4->-r requirements.txt (line 6))
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (3.3.0)
# Collecting protobuf<3.20,>=3.9.2 (from tensorflow==2.8.4->-r requirements.txt (line 6))
#   Downloading protobuf-3.19.6-cp310-cp310-win_amd64.whl.metadata (806 bytes)
# Requirement already satisfied: setuptools in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (57.4.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (1.16.0)
# Collecting tensorboard<2.9,>=2.8 (from tensorflow==2.8.4->-r requirements.txt (line 6))
#   Downloading tensorboard-2.8.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting tensorflow-estimator<2.9,>=2.8 (from tensorflow==2.8.4->-r requirements.txt (line 6))
#   Downloading tensorflow_estimator-2.8.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (1.65.4)
# Requirement already satisfied: certifi in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from kaggle==1.5.13->-r requirements.txt (line 8)) (2024.7.4)
# Requirement already satisfied: requests in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from kaggle==1.5.13->-r requirements.txt (line 8)) (2.32.3)
# Collecting tqdm (from kaggle==1.5.13->-r requirements.txt (line 8))
#   Using cached tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Collecting python-slugify (from kaggle==1.5.13->-r requirements.txt (line 8))
#   Downloading python_slugify-8.0.4-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: urllib3 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from kaggle==1.5.13->-r requirements.txt (line 8)) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from pandas==1.4.2->-r requirements.txt (line 9)) (2024.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow==2.8.4->-r requirements.txt (line 6)) (0.44.0)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6))
#   Downloading google_auth-2.35.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6))
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6)) (3.6)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6))
#   Downloading tensorboard_data_server-0.6.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6))
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl.metadata (873 bytes)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6)) (3.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from requests->kaggle==1.5.13->-r requirements.txt (line 8)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from requests->kaggle==1.5.13->-r requirements.txt (line 8)) (3.9)
# Collecting text-unidecode>=1.3 (from python-slugify->kaggle==1.5.13->-r requirements.txt (line 8))
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting colorama (from tqdm->kaggle==1.5.13->-r requirements.txt (line 8))
#   Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6))
#   Downloading cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6))
#   Downloading pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6))
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6))
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6)) (2.1.5)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6))
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6))
#   Downloading oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Downloading nibabel-5.1.0-py3-none-any.whl (3.3 MB)
#    ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#    ---------------------------------------- 3.3/3.3 MB 24.2 MB/s eta 0:00:00
# Downloading matplotlib-3.5.1-cp310-cp310-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------  7.1/7.2 MB 39.6 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 31.7 MB/s eta 0:00:00
# Downloading scikit_image-0.20.0-cp310-cp310-win_amd64.whl (23.7 MB)
#    ---------------------------------------- 0.0/23.7 MB ? eta -:--:--
#    -------- ------------------------------- 5.2/23.7 MB 39.8 MB/s eta 0:00:01
#    -------- ------------------------------- 5.2/23.7 MB 39.8 MB/s eta 0:00:01
#    -------- ------------------------------- 5.2/23.7 MB 39.8 MB/s eta 0:00:01
#    ------------------- -------------------- 11.8/23.7 MB 13.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 20.4/23.7 MB 19.3 MB/s eta 0:00:01
#    ---------------------------------------- 23.7/23.7 MB 18.5 MB/s eta 0:00:00
# Downloading scikit_learn-1.0.2-cp310-cp310-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------  7.1/7.2 MB 43.7 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 31.6 MB/s eta 0:00:00
# Downloading opencv_python-4.7.0.68-cp37-abi3-win_amd64.whl (38.2 MB)
#    ---------------------------------------- 0.0/38.2 MB ? eta -:--:--
#    ---------- ----------------------------- 9.7/38.2 MB 46.3 MB/s eta 0:00:01
#    -------------------- ------------------- 19.1/38.2 MB 46.4 MB/s eta 0:00:01
#    ------------------------------ --------- 28.8/38.2 MB 44.6 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.2 MB 45.5 MB/s eta 0:00:01
#    ---------------------------------------- 38
2 MB/s eta 0:00:02
#    ---------------------------------- ---- 384.0/438.4 MB 37.4 MB/s eta 0:00:02
#    ---------------------------------- ---- 392.7/438.4 MB 37.5 MB/s eta 0:00:02
#    ----------------------------------- --- 401.1/438.4 MB 37.3 MB/s eta 0:00:01
#    ------------------------------------ -- 406.6/438.4 MB 36.9 MB/s eta 0:00:01
#    ------------------------------------ -- 414.2/438.4 MB 36.6 MB/s eta 0:00:01
#    ------------------------------------- - 421.8/438.4 MB 36.4 MB/s eta 0:00:01
#    --------------------------------------  429.7/438.4 MB 36.1 MB/s eta 0:00:01
#    --------------------------------------  436.2/438.4 MB 35.7 MB/s eta 0:00:01
#    --------------------------------------  438.3/438.4 MB 35.4 MB/s eta 0:00:01
#    --------------------------------------  438.3/438.4 MB 35.4 MB/s eta 0:00:01
#    --------------------------------------  438.3/438.4 MB 35.4 MB/s eta 0:00:01
#    --------------------------------------  438.3/438.4 MB 35.4 MB/s eta 0:00:01
#    --------------------------------------  438.3/438.4 MB 35.4 MB/s eta 0:00:01
#    --------------------------------------  438.3/438.4 MB 35.4 MB/s eta 0:00:01
#    --------------------------------------  438.3/438.4 MB 35.4 MB/s eta 0:00:01
#    --------------------------------------  438.3/438.4 MB 35.4 MB/s eta 0:00:01
#    --------------------------------------  438.3/438.4 MB 35.4 MB/s eta 0:00:01
#    --------------------------------------  438.3/438.4 MB 35.4 MB/s eta 0:00:01
#    --------------------------------------- 438.4/438.4 MB 27.2 MB/s eta 0:00:00
# Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 23.8 MB/s eta 0:00:00
# Downloading pandas-1.4.2-cp310-cp310-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    -------- ------------------------------- 2.4/10.6 MB 16.8 MB/s eta 0:00:01
#    -------------------------- ------------- 7.1/10.6 MB 16.8 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 17.8 MB/s eta 0:00:00
# Downloading imageio-2.35.1-py3-none-any.whl (315 kB)
# Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading protobuf-3.19.6-cp310-cp310-win_amd64.whl (895 kB)
#    ---------------------------------------- 0.0/895.7 kB ? eta -:--:--
#    --------------------------------------- 895.7/895.7 kB 20.4 MB/s eta 0:00:00
# Downloading pywavelets-1.7.0-cp310-cp310-win_amd64.whl (4.3 MB)
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ---------------------------------------- 4.3/4.3 MB 25.6 MB/s eta 0:00:00
# Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#    ---------------------------------------- 0.0/5.8 MB ? eta -:--:--
#    ---------------------------------------- 5.8/5.8 MB 29.5 MB/s eta 0:00:00
# Downloading tensorflow_estimator-2.8.0-py2.py3-none-any.whl (462 kB)
# Downloading tifffile-2024.9.20-py3-none-any.whl (228 kB)
# Downloading python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Using cached tqdm-4.66.5-py3-none-any.whl (78 kB)
# Downloading google_auth-2.35.0-py2.py3-none-any.whl (208 kB)
# Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Downloading tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#    ---------------------------------------- 0.0/781.3 kB ? eta -:--:--
#    --------------------------------------- 781.3/781.3 kB 11.0 MB/s eta 0:00:00
# Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Downloading pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py): started
#   Building wheel for kaggle (setup.py): finished with status 'done'
#   Created wheel for kaggle: filename=kaggle-1.5.13-py3-none-any.whl size=77742 sha256=925516b814af84da07213c8df876d9e0e8f1ffc82c35b96d7aeff8b823716186
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\f3\16\ff\34e7d368370d4fd68bb749a59f1d2639ed66f3c14358e340a1
# Successfully built kaggle
# Installing collected packages: text-unidecode, tensorflow-estimator, tensorboard-plugin-wit, keras, tifffile, tensorboard-data-server, PyWavelets, python-slugify, pyasn1, protobuf, opencv-python, oauthlib, nibabel, lazy_loader, keras-preprocessing, imageio, colorama, cachetools, tqdm, scikit-learn, scikit-image, rsa, requests-oauthlib, pyasn1-modules, pandas, matplotlib, kaggle, google-auth, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: keras
#     Found existing installation: keras 3.5.0
#     Uninstalling keras-3.5.0:
#       Successfully uninstalled keras-3.5.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.2
#     Uninstalling tensorboard-data-server-0.7.2:
#       Successfully uninstalled tensorboard-data-server-0.7.2
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.4
#     Uninstalling protobuf-4.25.4:
#       Successfully uninstalled protobuf-4.25.4
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.10.0.84
#     Uninstalling opencv-python-4.10.0.84:
#       Successfully uninstalled opencv-python-4.10.0.84
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.5.1
#     Uninstalling scikit-learn-1.5.1:
#       Successfully uninstalled scikit-learn-1.5.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.9.2
#     Uninstalling matplotlib-3.9.2:
#       Successfully uninstalled matplotlib-3.9.2
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.17.0
#     Uninstalling tensorboard-2.17.0:
#       Successfully uninstalled tensorboard-2.17.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.17.0
#     Uninstalling tensorflow-2.17.0:
#       Successfully uninstalled tensorflow-2.17.0
# Successfully installed PyWavelets-1.7.0 cachetools-5.5.0 colorama-0.4.6 google-auth-2.35.0 google-auth-oauthlib-0.4.6 imageio-2.35.1 kaggle-1.5.13 keras-2.8.0 keras-preprocessing-1.1.2 lazy_loader-0.4 matplotlib-3.5.1 nibabel-5.1.0 oauthlib-3.2.2 opencv-python-4.7.0.68 pandas-1.4.2 protobuf-3.19.6 pyasn1-0.6.1 pyasn1-modules-0.4.1 python-slugify-8.0.4 requests-oauthlib-2.0.0 rsa-4.9 scikit-image-0.20.0 scikit-learn-1.0.2 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.8.4 tensorflow-estimator-2.8.0 text-unidecode-1.3 tifffile-2024.9.20 tqdm-4.66.5
# WARNING: The candidate selected for download or install is a yanked version: 'opencv-python' candidate (version 4.7.0.68 at https://files.pythonhosted.org/packages/80/5b/6eee3a1dc0f296904f44a13749f3b2cd29569c817aa931ead50c4d085d51/opencv_python-4.7.0.68-cp37-abi3-win_amd64.whl (from https://pypi.org/simple/opencv-python/) (requires-python:>=3.6))
# Reason for being yanked: Deprecated, use 4.7.0.71
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mediapipe 0.10.14 requires protobuf<5,>=4.25.3, but you have protobuf 3.19.6 which is incompatible.
# tensorflow-intel 2.17.0 requires keras>=3.2.0, but you have keras 2.8.0 which is incompatible.
# tensorflow-intel 2.17.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.19.6 which is incompatible.
# tensorflow-intel 2.17.0 requires tensorboard<2.18,>=2.17, but you have tensorboard 2.8.0 which is incompatible.

# %% [markdown]
# ### Importing Libraries

# %%
import nibabel as nib
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from skimage.transform import rotate
from skimage.util import montage
import os
from sklearn.model_selection import train_test_split
import keras
import cv2
import tensorflow
import random
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
import numpy as np
from keras.callbacks import CSVLogger
import keras.backend as K
import zipfile
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import nibabel as nib
#       2 import matplotlib as mpl
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'nibabel'
